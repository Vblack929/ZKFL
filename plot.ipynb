# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
# ours = np.loadtxt("log/fl_200.txt")
fl_noise_1 = np.loadtxt("log/noise05.txt")
fl_noise_2 = np.loadtxt("log/noise1.txt")
fl_noise_3 = np.loadtxt("log/noise_15.txt")
ours = np.loadtxt("log/vanilla_acc_200.txt")
# plot these accuracy in the same plot
fig, ax = plt.subplots()
ax.plot(ours, label="Ours")
ax.plot(fl_noise_1, label="noise level = 0.5")
ax.plot(fl_noise_2, label="noise level = 1")
ax.plot(fl_noise_3, label="noise level = 1.5")
# ax.plot(cl, label="CL")
ax.set(xlabel='Round', ylabel='Accuracy',
       )
# plt.title("MNIST")
ax.grid(True, which='both', linestyle='--')
plt.legend()
plt.show()
# plt.savefig("cifar_noise.png")

# %%
fig.savefig("cifar_noise.png")

# %%
no_byz = np.loadtxt("log/fl_200.txt")
byz = np.loadtxt("log/vanilla_acc_200.txt")
fig, ax = plt.subplots()
ax.plot(no_byz, label="No Byzantine")
ax.plot(byz, label="Byzantine")
ax.set(xlabel='Round', ylabel='Accuracy',
       )
ax.grid(True, which='both', linestyle='--') 
plt.legend()
plt.show()

# %%
fig.savefig("cifar_byzantine.png")
